# %%
s = "anagram"
t = "nagaram"

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        
        dict_s = {}
        dict_t = {}

        for l in s:
            if l not in dict_s:
                dict_s[l] = 1
            else:
                dict_s[l] +=1

        for l in t:
            if l not in dict_t:
                dict_t[l] = 1
            else:
                dict_t[l] +=1

        print(dict_s, dict_t)
        return dict_s == dict_t
                

Solution().isAnagram(s, t)
# Out:
# {'a': 3, 'n': 1, 'g': 1, 'r': 1, 'm': 1} {'n': 1, 'a': 3, 'g': 1, 'r': 1, 'm': 1}
# True

# %%
from collections import Counter
def isAnagram( s, t):
    return Counter(s) == Counter(t)

isAnagram(s,t)
# Out:
# True

# %%
# Given a string s, return true if the s can be palindrome after deleting at most one character from it.
#s = "dabcad"
s = "acwddca"
class Solution:
    def validPalindrome(self, s: str) -> bool:
        left,right=0,len(s)-1
        while left<right:
            print(left, right)
            if s[left]!=s[right]:
                left_s=s[left:right]
                right_s=s[left+1:right+1]

                print(left_s, right_s)
                return left_s==left_s[::-1] or right_s==right_s[::-1]
            left+=1
            right-=1
        return True

Solution().validPalindrome(s)
# Out:
# 0 6
# 1 5
# 2 4
# wd dd
# True

# %%
print(Solution().validPalindrome("dabcad"))  # True
print(Solution().validPalindrome("aba"))     # True
print(Solution().validPalindrome("abc"))     # False
# Out:
# True
# True
# False

# %%
#final = s.replace(Solution().validPalindrome(s)[-1],"")
#final

# %%
#Input: strs = ["eat","tea","tan","ate","nat","bat"]
#Output: [["bat"],["nat","tan"],["ate","eat","tea"]]

from typing import List, Dict

strs = ["eat","tea","tan","ate","nat","bat"] 

class Solution:
    def groupAnagrams(self, strs :List[str]) -> List[List[str]]:
        groups : Dict[List] = {}
        
        for s in strs:
            key = "".join(sorted(s))
            
            if key not in groups:
                groups[key] = []
            
            #print(groups, key , s)
            
            groups[key].append(s)
                        
        return list(groups.values())

Solution().groupAnagrams(strs)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
s = "babd"
#Output: "bab"


class Solution:
    def longestPalindrome(self, s: str) -> str:
        if len(s) <=1:
            return s

        max_len = 0
        max_str = s[0]
        
        for i in range(len(s) -1 ):
            for j in range( i+1 , len(s)):

                if j-i+1 > max_len and s[i:j+1] == s[i:j+1][::-1]:
                    
                    max_len = j-i+1
                    max_str = s[i:j+1]

                print(i,j, max_str, max_len)

        return max_str
            
Solution().longestPalindrome(s)
#"babd"
# Out:
# 0 1 b 0
# 0 2 bab 3
# 0 3 bab 3
# 1 2 bab 3
# 1 3 bab 3
# 2 3 bab 3
# 'bab'

# %%
s = 'aabc'
for i in range(  len(s) - 1 ):
    for j in range( i+1, len(s)):
        print(i, j)
    
    print(i)
# Out:
# 0 1
# 0 2
# 0 3
# 0
# 1 2
# 1 3
# 1
# 2 3
# 2
